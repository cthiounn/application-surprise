# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("movie_metadata.csv")

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movies["director_name"].unique()
# Out:
# array(['James Cameron', 'Gore Verbinski', 'Sam Mendes', ...,
#        'Scott Smith', 'Benjamin Roberds', 'Daniel Hsia'], dtype=object)

# %%
movies[movies['director_name'] == 'James Cameron']
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 288   Color  James Cameron                   210.0     153.0
# 291   Color  James Cameron                    94.0     141.0
# 606   Color  James Cameron                    82.0     171.0
# 2486  Color  James Cameron                   250.0     154.0
# 3575  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 288                       0.0                   539.0  Jenette Goldstein
# 291                       0.0                   618.0        Tia Carrere
# 606                       0.0                   638.0         Todd Graff
# ...

# %%
movies2 = movies[['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'movie_title', 'imdb_score', 'title_year']]

# %%
movies2[(movies2['title_year']<2000) & (movies2['title_year']>1990)]
# Out:
#           director_name        actor_1_name       actor_2_name  \
# 26        James Cameron   Leonardo DiCaprio       Kate Winslet
# 71     Barry Sonnenfeld          Will Smith        Salma Hayek
# 76       Kevin Reynolds  Jeanne Tripplehorn        Rick Aviles
# 151         Michael Bay        Bruce Willis      Steve Buscemi
# 166      Richard Donner              Jet Li         Rene Russo
# ...                 ...                 ...                ...
# 5011        Neil LaBute       Stacy Edwards        Matt Malloy
# 5015  Richard Linklater      Tommy Pallotta  Richard Linklater
# 5029   Kiyoshi Kurosawa        Kôji Yakusho      Anna Nakagawa
# 5032    Ash Baron-Cohen        Peter Greene  Stanley B. Herman
# 5035   Robert Rodriguez     Carlos Gallardo    Peter Marquardt
#
#         actor_3_name             movie_title  imdb_score  title_year
# 26     Gloria Stuart                Titanic          7.7      1997.0
# 71          Bai Ling         Wild Wild West          4.8      1999.0
# ...

# %%
movies_1990 = movies2[movies2['title_year']<1990]

# %%
movies_1990.to_csv("movies_1990.csv")
